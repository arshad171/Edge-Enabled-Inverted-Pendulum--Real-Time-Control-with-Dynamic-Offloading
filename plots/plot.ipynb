# %%
import os
import pandas as pd
import numpy as np
import json
import pickle
import torch as th
from torch.utils.data import Dataset, DataLoader, random_split
from scipy.stats import gaussian_kde

from import_plotting import *
from utils import *

FILL = False
SAVE_FIGS = True
SAVE_RES = True
# DATA_P95_FOLDER = f"/Users/arshadjaveed/My Data/Workspace/Edge-Enabled-Inverted-Pendulum--Real-Time-Control-with-Dynamic-Offloading/data_c3m6/pair"
DATA_P95_FOLDER = f"/home/arshad/code/Edge-Enabled-Inverted-Pendulum--Real-Time-Control-with-Dynamic-Offloading/data_c32m40/pair"

# SIG_PATH = f"{HOME_PATH}" + "/data/pairwise_exps/contention_params_sig_{}.json"

# %%
app1 = "visual-servo"

print(app1)

lam = 1.0
lams = {
    "visual-servo": 2,
    "iclf-efnet": 1,
    "text-tbert": 1,
}
# ni = 4

plt.figure()

# applications = ["visual-servo", "iclf-efnet", "text-tbert"]
applications = ["visual-servo"]

for app2 in applications:
    lam = lams[app2]
    # df_sts = get_p95_lam_ret_all_ni_ten0(app1, app2, lam, DATA_P95_FOLDER)
    df_sts = get_p95_lam_ret_all_ni_ten0(app1, app2, lam, DATA_P95_FOLDER)
    sns.lineplot(df_sts, x="ni", y="sts", color=COLOR_PALETTE[app2], label=app2)

plt.legend(loc="upper left", bbox_to_anchor=(1, 1))
plt.grid()
plt.xlabel("No. of instances")
plt.ylabel("Inference time [s]")

# save_fig("pairwise_mnet")
plt.show()
# Out:
# visual-servo
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[13], line 30
#      27 plt.ylabel("Inference time [s]")
#      29 # save_fig("pairwise_mnet")
# ---> 30 get_ipython().run_line_magic('matplotlib', 'qt')
#      31 plt.show()
#
# File ~/anaconda3/envs/pa_res_alloc/lib/python3.10/site-packages/IPython/core/interactiveshell.py:2417, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2415     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2416 with self.builtin_trap:
# -> 2417     result = fn(*args, **kwargs)
#    2419 # The code below prevents the output from being displayed
#    2420 # when using magics with decodator @output_can_be_silenced
#    2421 # when the last Python token in the expression is a ';'.
#    2422 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# ...
